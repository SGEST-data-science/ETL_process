# %% [markdown]
# ## Install the necessary python modules

# %%
pip install pandas
pip install sqlalchemy

# %%
pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#                                               0.0/1.2 MB ? eta -:--:--
#      ---------------------------------------  1.1/1.2 MB 23.7 MB/s eta 0:00:01
#      ---------------------------------------  1.1/1.2 MB 23.7 MB/s eta 0:00:01
#      ---------------------------------------  1.1/1.2 MB 9.1 MB/s eta 0:00:01
#      ---------------------------------------- 1.2/1.2 MB 6.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import py modules to work with SQL and DataFrames

# %%
from sqlalchemy  import create_engine 
import pandas as pd
import psycopg2

# %%
# Connect to database
pgconn = psycopg2.connect(
    host = '10.83.0.131', 
    user = 'sgest_saber',
    password = 'Tq712f&f',
    database = 'postgres'
)
pgconn
# Out:
# <connection object at 0x0000020EA5356480; dsn: 'user=sgest_saber password=xxx dbname=postgres host=10.83.0.131', closed: 0>

# %%
#set cursor
pgcursor = pgconn.cursor()

# %%
#requerid code
from psycopg2.extensions import ISOLATION

# %% [markdown]
# ## Load  and Transform Data

# %%
df = pd.read_excel('C:/Users/benna/AppData/Roaming/Python/Python38/Scripts/databases/schema_paraiba/xlsx_tipo.xlsx' , sheet_name = 'MODALIDADE')
df = df.drop([0,1,2])
df
# Out:
#      Unnamed: 0   Unnamed: 1  \
# 3           NaN          GRE
# 4           NaN      01ª GRE
# 5           NaN      01ª GRE
# 6           NaN      01ª GRE
# 7           NaN      01ª GRE
# ..          ...          ...
# 641         NaN      14ª GRE
# 642         NaN      14ª GRE
# 643         NaN      14ª GRE
# 644         NaN      14ª GRE
# 645         NaN  Total Geral
#
#                                             Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 3                                               ESCOLA       INEP     MODELO
# 4                               CEEEA Sesquicentenario   25092839    Regular
# 5                     Centro Profis Dep Antonio Cabral   25092871    Regular
# 6           Cpm-Estudante Rebeca Cristina Alves Simões   25094122    Regular
# 7                             CRIA Capistrano de Abreu   25093754    Regular
# ..                                                 ...        ...        ...
# ...

# %%
df.columns = df.iloc[0]
df
# Out:
# 3   NaN          GRE                                             ESCOLA  \
# 3   NaN          GRE                                             ESCOLA
# 4   NaN      01ª GRE                             CEEEA Sesquicentenario
# 5   NaN      01ª GRE                   Centro Profis Dep Antonio Cabral
# 6   NaN      01ª GRE         Cpm-Estudante Rebeca Cristina Alves Simões
# 7   NaN      01ª GRE                           CRIA Capistrano de Abreu
# ..   ..          ...                                                ...
# 641 NaN      14ª GRE                       EEIEFM Guilherme da Silveira
# 642 NaN      14ª GRE                                  EEIEFM Pedro Poti
# 643 NaN      14ª GRE  Escola Cidadã Integral de Ensino Fundamental e...
# 644 NaN      14ª GRE  Escola Cidadã Integral E.E.F.M Senador Rui Car...
# 645 NaN  Total Geral                                                NaN
#
# 3        INEP   MODELO     TIPO  CAMPO  EDUC_ESPECIAL  EJA  ENSINO_REGULAR  \
# ...

# %%
df = df.drop([3])
df
# Out:
# 3   NaN          GRE                                             ESCOLA  \
# 4   NaN      01ª GRE                             CEEEA Sesquicentenario
# 5   NaN      01ª GRE                   Centro Profis Dep Antonio Cabral
# 6   NaN      01ª GRE         Cpm-Estudante Rebeca Cristina Alves Simões
# 7   NaN      01ª GRE                           CRIA Capistrano de Abreu
# 8   NaN      01ª GRE                             Cria Capitulina Satyro
# ..   ..          ...                                                ...
# 641 NaN      14ª GRE                       EEIEFM Guilherme da Silveira
# 642 NaN      14ª GRE                                  EEIEFM Pedro Poti
# 643 NaN      14ª GRE  Escola Cidadã Integral de Ensino Fundamental e...
# 644 NaN      14ª GRE  Escola Cidadã Integral E.E.F.M Senador Rui Car...
# 645 NaN  Total Geral                                                NaN
#
# 3        INEP   MODELO     TIPO CAMPO  EDUC_ESPECIAL  EJA ENSINO_REGULAR  ...  \
# ...

# %%
df
# Out:
# 3   NaN          GRE                                             ESCOLA  \
# 4   NaN      01ª GRE                             CEEEA Sesquicentenario
# 5   NaN      01ª GRE                   Centro Profis Dep Antonio Cabral
# 6   NaN      01ª GRE         Cpm-Estudante Rebeca Cristina Alves Simões
# 7   NaN      01ª GRE                           CRIA Capistrano de Abreu
# 8   NaN      01ª GRE                             Cria Capitulina Satyro
# ..   ..          ...                                                ...
# 641 NaN      14ª GRE                       EEIEFM Guilherme da Silveira
# 642 NaN      14ª GRE                                  EEIEFM Pedro Poti
# 643 NaN      14ª GRE  Escola Cidadã Integral de Ensino Fundamental e...
# 644 NaN      14ª GRE  Escola Cidadã Integral E.E.F.M Senador Rui Car...
# 645 NaN  Total Geral                                                NaN
#
# 3        INEP   MODELO     TIPO CAMPO  EDUC_ESPECIAL  EJA ENSINO_REGULAR  ...  \
# ...

# %%
df
# Out:
# 3    NaN      INEP   MODELO     TIPO  NaN
# 4    NaN  25092839  Regular  Regular  NaN
# 5    NaN  25092871  Regular  Regular  NaN
# 6    NaN  25094122  Regular  Regular  NaN
# 7    NaN  25093754  Regular  Regular  NaN
# 8    NaN  25094084  Regular  Regular  NaN
# ..   ...       ...      ...      ...  ...
# 641  NaN  25087878  Regular  Regular  NaN
# 642  NaN  25120778  Regular  Regular  NaN
# 643  NaN  25087738   Cidadã      ECI  NaN
# 644  NaN  25086901   Cidadã      ECI  NaN
# 645  NaN       NaN      NaN      NaN  NaN
#
# [642 rows x 5 columns]

# %%
df_new = df.drop(df.columns[[0 , 4]] , axis = 1)
df_new
# Out:
# 3        INEP   MODELO     TIPO
# 4    25092839  Regular  Regular
# 5    25092871  Regular  Regular
# 6    25094122  Regular  Regular
# 7    25093754  Regular  Regular
# 8    25094084  Regular  Regular
# ..        ...      ...      ...
# 641  25087878  Regular  Regular
# 642  25120778  Regular  Regular
# 643  25087738   Cidadã      ECI
# 644  25086901   Cidadã      ECI
# 645       NaN      NaN      NaN
#
# [642 rows x 3 columns]

# %% [markdown]
# ## Convert to CSV to import to POSTGRESQL

# %%
df_new.to_csv('C:/Users/benna/AppData/Roaming/Python/Python38/Scripts/databases/schema_paraiba/escola_cidada.csv')

# %% [markdown]
# ## Importing directly to database

# %%
##In test
