# %% [markdown]
# ## Algorithom used in this work
# #### ETL Process in this work
# ##### 1 - Extract -> Extract data from an sheet of a xlsx file
# ##### 2 - Transform -> Choose relevant columns and delete irrelevant columns using in one pythonic way
# ##### 3 - Load -> Convert the data frame to CSV file, this CSV gona be readed from DBEAVER DBMS for create table in the correct schema

# %%
### Import pandas to read data 
import pandas as pd

# %%
##Extract
df = pd.read_excel('C:/Users/benna/AppData/Roaming/Python/Python38/Scripts/databases/schema_public/auxiliar_distrito_xlsx.xlsx',
             sheet_name = 'aux_distrito'
             )
df
# Out:
#                                                           Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira  \
# 0                                                    ...
# 1                                                    ...
# 2                                                    ...
# 3                                                    NaN
# 4                                     Censo Escolar 2023
# ...                                                  ...
# 10672                                                 52
# 10673                                                 52
# 10674                                                 52
# 10675                                                 52
# 10676                                                 53
#
#              Unnamed: 1 Unnamed: 2      Unnamed: 3 Unnamed: 4  \
# 0                   NaN        NaN             NaN        NaN
# 1                   NaN        NaN             NaN        NaN
# ...

# %%
df = df.drop([0 , 1 , 2, 3 , 4 , 5 ] , axis = 0)
df
# Out:
#                                                           Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira  \
# 6                                              codigo UF
# 7                                                     11
# 8                                                     11
# 9                                                     11
# 10                                                    11
# ...                                                  ...
# 10672                                                 52
# 10673                                                 52
# 10674                                                 52
# 10675                                                 52
# 10676                                                 53
#
#              Unnamed: 1           Unnamed: 2             Unnamed: 3  \
# 6                    UF  Código do município      Nome do município
# 7              Rondônia              1100015  Alta Floresta D'Oeste
# ...

# %%
df.columns = df.iloc[0]
df
# Out:
# 6      codigo UF                UF  Código do município  \
# 6      codigo UF                UF  Código do município
# 7             11          Rondônia              1100015
# 8             11          Rondônia              1100015
# 9             11          Rondônia              1100015
# 10            11          Rondônia              1100015
# ...          ...               ...                  ...
# 10672         52             Goiás              5222054
# 10673         52             Goiás              5222203
# 10674         52             Goiás              5222302
# 10675         52             Goiás              5222302
# 10676         53  Distrito Federal              5300108
#
# 6          Nome do município  Código do distrito       Nome do distrito
# 6          Nome do município  Código do distrito       Nome do distrito
# 7      Alta Floresta D'Oeste           110001505  Alta Floresta D'Oeste
# 8      Alta Floresta D'Oeste           110001535  Santo Antônio d'Oeste
# ...

# %%
df = df.drop([6] , axis = 0)

# %%
df
# Out:
# 6     codigo UF                UF Código do município      Nome do município  \
# 7            11          Rondônia             1100015  Alta Floresta D'Oeste
# 8            11          Rondônia             1100015  Alta Floresta D'Oeste
# 9            11          Rondônia             1100015  Alta Floresta D'Oeste
# 10           11          Rondônia             1100015  Alta Floresta D'Oeste
# 11           11          Rondônia             1100015  Alta Floresta D'Oeste
# ...         ...               ...                 ...                    ...
# 10672        52             Goiás             5222054         Vicentinópolis
# 10673        52             Goiás             5222203               Vila Boa
# 10674        52             Goiás             5222302          Vila Propício
# 10675        52             Goiás             5222302          Vila Propício
# 10676        53  Distrito Federal             5300108               Brasília
#
# ...

# %%
df = df.drop(columns = ['UF' , 'Código do município' , 'Nome do município' ])

# %%
df
# Out:
# 6     Código do distrito           Nome do distrito
# 7              110001505      Alta Floresta D'Oeste
# 8              110001535      Santo Antônio d'Oeste
# 9              110001520                Izidolândia
# 10             110001525         Nova Gease d'Oeste
# 11             110001530  Rolim de Moura do Guaporé
# ...                  ...                        ...
# 10672          522205405             Vicentinópolis
# 10673          522220305                   Vila Boa
# 10674          522230210          Assunção de Goiás
# 10675          522230205              Vila Propício
# 10676          530010805                   Brasília
#
# [10670 rows x 2 columns]

# %%
### All right, now generate the CSV file!
df.to_csv('C:/Users/benna/AppData/Roaming/Python/Python38/Scripts/databases/schema_public/csv/aux_distrito.csv', index=False, encoding = 'utf-8')
